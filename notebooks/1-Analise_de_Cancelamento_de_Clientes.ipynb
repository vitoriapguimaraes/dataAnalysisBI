# %% [markdown]
# # Análise de Cancelamento de Cartão de Crédito
#
# Este notebook tem como objetivo realizar uma análise profunda do dataset para identificar os motivos de cancelamento (Churn) de clientes.

# %%
import sys
from pathlib import Path

import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.templates.default = "plotly_white"

# %%
ROOT_DIR = Path().resolve().parent
if str(ROOT_DIR) not in sys.path:
    sys.path.append(str(ROOT_DIR))
    
from utils.paths import DATA_DIR
from utils.load_file import load_dataset

# %% [markdown]
# ## Carregar Dados

# %%
file_name = "bank_credit_card_cancellation.csv"

try:
    df = load_dataset(file_name)
except FileNotFoundError:
    raise FileNotFoundError(f"Arquivo não encontrado em {DATA_DIR / file_name}")
except Exception as e:
    raise RuntimeError(f"Erro ao carregar dataset: {e}")

df.head()
# Out:
#    CLIENTNUM Categoria  Idade Sexo  Dependentes           Educação  \
# 0  768805383   Cliente     45    M            3       Ensino Médio
# 1  818770008   Cliente     49    F            5    Ensino Superior
# 2  713982108   Cliente     51    M            3    Ensino Superior
# 3  769911858   Cliente     40    F            4       Ensino Médio
# 4  709106358   Cliente     40    M            3  Sem ensino formal
#
#     Estado Civil Faixa Salarial Anual Categoria Cartão  Meses como Cliente  \
# 0         Casado          $60K - $80K             Blue                  39
# 1       Solteiro       Less than $40K             Blue                  44
# 2         Casado         $80K - $120K             Blue                  36
# 3  Não informado       Less than $40K             Blue                  34
# 4         Casado          $60K - $80K             Blue                  21
#
#    ...  Inatividade 12m  Contatos 12m   Limite  Limite Consumido  \
# 0  ...                1             3  12691.0               777
# 1  ...                1             2   8256.0               864
# 2  ...                1             0   3418.0                 0
# 3  ...                4             1   3313.0              2517
# 4  ...                1             0   4716.0                 0
#
#    Limite Disponível  Mudanças Transacoes_Q4_Q1  Valor Transacoes 12m  \
# 0            11914.0                     1335.0                  1144
# 1             7392.0                     1541.0                  1291
# 2             3418.0                     2594.0                  1887
# 3              796.0                     1405.0                  1171
# 4             4716.0                     2175.0                   816
#
#    Qtde Transacoes 12m  Mudança Qtde Transações_Q4_Q1  \
# 0                   42                         1625.0
# 1                   33                         3714.0
# 2                   20                         2333.0
# 3                   20                         2333.0
# 4                   28                            2.5
#
#    Taxa de Utilização Cartão
# 0                      0.061
# 1                      0.105
# 2                      0.000
# 3                      0.760
# 4                      0.000
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (10127, 21)

# %% [markdown]
# ## 1. Limpeza de Dados

# %%
# Remover colunas irrelevantes
cols_to_drop = ["CLIENTNUM"]
cols_to_drop += [c for c in df.columns if "Naive_Bayes" in c]

df_clean = df.drop(columns=cols_to_drop, errors="ignore")

print(f"Colunas removidas ({len(cols_to_drop)}): {cols_to_drop}")
print(f"Shape após limpeza: {df_clean.shape}")
# Out:
# Colunas removidas (1): ['CLIENTNUM']
# Shape após limpeza: (10127, 20)

# %%
# Valores ausentes
missing = df_clean.isnull().sum()
missing = missing[missing > 0]

print("Valores ausentes:")
display(missing if not missing.empty else "Nenhum valor ausente")

# Duplicatas
duplicates = df_clean.duplicated().sum()
print(f"Duplicatas: {duplicates}")
# Out:
# Valores ausentes:
# Categoria Cartão    1
# dtype: int64
# Duplicatas: 0

# %% [markdown]
# ## 2. Análise Univariada

# %%
num_cols = df_clean.select_dtypes(include="number").columns.tolist()
cat_cols = df_clean.select_dtypes(exclude="number").columns.tolist()

print(f"Numéricas ({len(num_cols)}): {num_cols}")
print(f"Categóricas ({len(cat_cols)}): {cat_cols}")
# Out:
# Numéricas (14): ['Idade', 'Dependentes', 'Meses como Cliente', 'Produtos Contratados', 'Inatividade 12m', 'Contatos 12m', 'Limite', 'Limite Consumido', 'Limite Disponível', 'Mudanças Transacoes_Q4_Q1', 'Valor Transacoes 12m', 'Qtde Transacoes 12m', 'Mudança Qtde Transações_Q4_Q1', 'Taxa de Utilização Cartão']
# Categóricas (6): ['Categoria', 'Sexo', 'Educação', 'Estado Civil', 'Faixa Salarial Anual', 'Categoria Cartão']

# %%
TARGET_COL = "Categoria"

if TARGET_COL not in df_clean.columns:
    raise ValueError(f"Coluna alvo '{TARGET_COL}' não encontrada")

fig = px.pie(
    df_clean,
    names=TARGET_COL,
    title="Distribuição de Cancelamento (Churn)",
    hole=0.4
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="409fbb70-22c3-4273-8d18-1fe142edd366" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("409fbb70-22c3-4273-8d18-1fe142edd366")) {                    Plotly.newPlot(                        "409fbb70-22c3-4273-8d18-1fe142edd366",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Categoria=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cancelado","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Clie ...

# %%
AGE_COL = "Idade"

fig = px.histogram(
    df_clean,
    x=AGE_COL,
    nbins=20,
    title="Distribuição de Idade dos Clientes"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bad8b8af-6719-42e8-95bc-1872379120ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bad8b8af-6719-42e8-95bc-1872379120ac")) {                    Plotly.newPlot(                        "bad8b8af-6719-42e8-95bc-1872379120ac",                        [{"bingroup":"x","hovertemplate":"Idade=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"...\u002fMS1DMDM0NyI4LC8uKzImNSs1ODY5Pi4xNDo2MTo0KT42KCs1Ny4pMT0uMigzMi8rJC8uLjQrKDY3MS0xPygpJTo3NTkrOkA2NSc4NjsqKis3NC45MC0wLyopMzdDJzY3LzEqOSw4MS0\u002fLCwoJyo2Oi4vQzI3Li8kKDkwOjAwNTI0NTgsMTYnJyk1Ly41PDsmOCMyNT8rLj0lKik4ODQoPzo6LiUuLikwMSwnOTAvODY2NCs7LDgtNzA4KUEiOD4tJjE6KSEvODMxMjcaOi4wKiU\...\u002fKiQqJSYdNiE\...\...\u002fMicnJzQlMjsmQTlBJik3HB8nLDc5HCMuQTIfMTIsPyk4NzAjHiU1JUEwJSMjMRo6HTohJC8pLjo1NicxIy8mODgmLiU\u002fQSYtGjowGjAhPjcoLjovMjUtMCs8OCs5NDgrJjU0OiIkNzYkIzUwJS02JiMkIRwkIjc9LDYnMy8lLzg1Pjo5NiE2HiQ8Ljc3HzckIiEeNjU7KS0yOT8jIzUhJh8lJCc6Jz0iNzIhMD82KTM2LzQiQD4mNCMjNiMjJCE1JSM7LzA6NyU5PDI4MCgwMj0kLhwxLDklOSEuLTU0Ijc1JTohJyUgGjwlKzg0Ii8aNiM0KSQ1KjY1JCobOjs\u002fOTgqHSwhIyEuGyo1MjA5Ijc6NzAtOzUvKyExNkExLzMkJC4+Hi4pMjU3MTg\\\u002fMC40LTA7Lzc1KSg0OyQ7KSYsKjA5IjIpMjEvLS8rJyQsLykqMC4uLjQ4JikzGjMpOSw0MTQsPyw1LzEjLS0kKi4xMjkuNyYjMDk3LyUwMTEwNCwpMy0xLywqPiArPi4+Kic7KzQ7PDAoNzAkMSg2KD8sLC0kLSYsIzc9KygzMEAxNi4iLjAtQS0oMigmJDYyMikuLDItKC4wLyorMS4pLSgoMTMrLSYoMS0\u002fKzIvPx4pJiwyMi4zNSgxNjItLjM\u002fNjM8HiwhKDQnMzMuLD41Ly0qLykuJC84NionLTQuMC4qLTIyJy00KjEzMDQrMSUwKDEuMjIsLzAxMzstMi4vLjwmMy8vMScsKDgtJSorOyouHC82Nz4xMCszMC8yOCsvMTAoKSsqJzIyMjMvKTEqKi0yNTMyQC00LyYtKzkvKjQwLCgyKSorLD0zKC4yMDIsKi40Ki8nNTQnPzU2LS00QC8tKTg0Jz05LiYsKDk0MjMqMy0sLTc\...\...\...\...\...\..."},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ## 3. Análise Bivariada (vs Churn)

# %%
TRANS_AMT_COL = "Valor Transacoes 12m"

fig = px.box(
    df_clean,
    x=TARGET_COL,
    y=TRANS_AMT_COL,
    title="Valor de Transações (12m) por Status"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="c0b1977c-0cb3-443d-ab9c-319ac17a9a71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c0b1977c-0cb3-443d-ab9c-319ac17a9a71")) {                    Plotly.newPlot(                        "c0b1977c-0cb3-443d-ab9c-319ac17a9a71",                        [{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eValor Transacoes 12m=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cancelado","Cancelado","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cliente","Cliente","Cliente","Cliente","Cancelado","Cliente","Cliente","Cancelado","Cliente","Cancelado","Cliente","Cliente","Cliente","Clie ...

# %%
CONTACTS_COL = "Contatos 12m"

fig = px.histogram(
    df_clean,
    x=CONTACTS_COL,
    color=TARGET_COL,
    barmode="group",
    title="Quantidade de Contatos (12m) vs Churn"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="3666aa5a-3609-42e9-8122-ee10d3554561" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3666aa5a-3609-42e9-8122-ee10d3554561")) {                    Plotly.newPlot(                        "3666aa5a-3609-42e9-8122-ee10d3554561",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Categoria=Cliente\u003cbr\u003eContatos 12m=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cliente","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cliente","offsetgroup":"Cliente","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Categoria=Cancelado\u003cbr\u003eContatos 12m=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cancelado","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cancelado","offsetgroup":"Cancelado","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"col ...

# %% [markdown]
# ## 4. Análise Multivariada (Correlação)

# %%
num_cols = df_clean.select_dtypes(include="number").columns

corr_matrix = df_clean[num_cols].corr()

fig = px.imshow(
    corr_matrix,
    aspect="auto",
    color_continuous_scale="RdBu_r",
    title="Mapa de Calor de Correlação"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id